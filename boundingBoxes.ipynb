# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image

# %%
data = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_2.csv")
data2 = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_6.csv")
data3 = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_7.csv")
data4 = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_15.csv")
data5 = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_17.csv")
data6 = pd.read_csv(r"C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Data\Image_20.csv")

# %%
xmin = data['object.bndbox.xmin']
xmax = data['object.bndbox.xmax']
ymin = data['object.bndbox.ymin']
ymax = data['object.bndbox.ymax']

xmin2 = data2['object.bndbox.xmin']
xmax2 = data2['object.bndbox.xmax']
ymin2 = data2['object.bndbox.ymin']
ymax2 = data2['object.bndbox.ymax']

xmin3 = data3['object.bndbox.xmin']
xmax3 = data3['object.bndbox.xmax']
ymin3 = data3['object.bndbox.ymin']
ymax3 = data3['object.bndbox.ymax']

xmin4 = data4['object.bndbox.xmin']
xmax4 = data4['object.bndbox.xmax']
ymin4 = data4['object.bndbox.ymin']
ymax4 = data4['object.bndbox.ymax']

xmin5 = data5['object.bndbox.xmin']
xmax5 = data5['object.bndbox.xmax']
ymin5 = data5['object.bndbox.ymin']
ymax5 = data5['object.bndbox.ymax']

xmin6 = data6['object.bndbox.xmin']
xmax6 = data6['object.bndbox.xmax']
ymin6 = data6['object.bndbox.ymin']
ymax6 = data6['object.bndbox.ymax']

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_2.png'))

for ii in range(len(xmin)):
    plt.gca().add_patch(Rectangle((xmin[ii],ymin[ii]),xmax[ii]-xmin[ii],ymax[ii]-ymin[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_6.png'))

for ii in range(len(xmin2)):
    plt.gca().add_patch(Rectangle((xmin2[ii],ymin2[ii]),xmax2[ii]-xmin2[ii],ymax2[ii]-ymin2[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_7.png'))

for ii in range(len(xmin3)):
    plt.gca().add_patch(Rectangle((xmin3[ii],ymin3[ii]),xmax3[ii]-xmin3[ii],ymax3[ii]-ymin3[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_15.png'))

for ii in range(len(xmin4)):
    plt.gca().add_patch(Rectangle((xmin4[ii],ymin4[ii]),xmax4[ii]-xmin4[ii],ymax4[ii]-ymin4[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_17.png'))

for ii in range(len(xmin5)):
    plt.gca().add_patch(Rectangle((xmin5[ii],ymin5[ii]),xmax5[ii]-xmin5[ii],ymax5[ii]-ymin5[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
# Display the image
plt.imshow(Image.open(r'C:\Users\Roarke\Desktop\University\2019 Semester 2 CURRENT\CITS4404\Project\CellData\Images\image_20.png'))

for ii in range(len(xmin6)):
    plt.gca().add_patch(Rectangle((xmin6[ii],ymin6[ii]),xmax6[ii]-xmin6[ii],ymax6[ii]-ymin6[ii],linewidth=1,edgecolor='r',facecolor='none'))

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow.keras import layers

print(tf.version.VERSION)
print(tf.keras.__version__)
# Out:
# 1.14.0
# 2.2.4-tf

# %%
model = tf.keras.Sequential()
# Adds a densely-connected layer with 64 units to the model:
model.add(layers.Dense(64, activation='relu'))
# Add another:
model.add(layers.Dense(64, activation='relu'))
# Add a softmax layer with 10 output units:
model.add(layers.Dense(10, activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0924 15:42:32.883501 16628 deprecation.py:506] From c:\users\roarke\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# Create a sigmoid layer:
layers.Dense(64, activation='sigmoid')

# %%
model = tf.keras.Sequential([
# Adds a densely-connected layer with 64 units to the model:
layers.Dense(64, activation='relu', input_shape=(32,)),
# Add another:
layers.Dense(64, activation='relu'),
# Add a softmax layer with 10 output units:
layers.Dense(10, activation='softmax')])

model.compile(optimizer=tf.train.AdamOptimizer(0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
