# %%
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn import visualize

# %%
# class that defines and loads the cell dataset
class CellDataset(Dataset):
    # load the dataset definitions
    def load_dataset(self, dataset_dir, is_train=True):
        # define one class
        self.add_class("dataset", 1, "cell")
        # image tags
        imgs = [2,6,7,15,17]
        # find all images
        # Traverse train data
        if is_train:
            for files in imgs:
                images_dir = dataset_dir + '/Training_Data_Set/image_' + str(files) +'/'
                annotations_dir = dataset_dir + '/Training_Data_Set/image_' + str(files) + '_XML/'   
                for filename in listdir(images_dir):
                    # extract image id
                    image_id = filename[:-4] 
                    img_path = images_dir + filename
                    ann_path = annotations_dir + image_id + '.xml'
                    # add to dataset
                    self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path) 
        # Traverse test data
        if not is_train: 
            images_dir = dataset_dir + '/Test_Data_Set/image_20/'
            annotations_dir = dataset_dir + '/Test_Data_Set/image_20_XML/'
            for filename in listdir(images_dir):
                image_id = filename[:-4]
                img_path = images_dir + filename
                ann_path = annotations_dir + image_id + '.xml'
                # add to dataset
                self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)
    # Used to detect cells on a full size image
    def load_final(self, dataset_dir):
        self.add_class("dataset", 1, "cell")
        images_dir = dataset_dir + '/Original_Cell_Images/'
        annotations_dir = dataset_dir + '/Original_XML_Annotations/'
        for filename in listdir(images_dir):
            image_id = filename[:-4]
            img_path = images_dir + filename
            ann_path = annotations_dir + image_id + '.xml'
            # add to dataset
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)
    
    # extract bounding boxes from an annotation/xml file
    def extract_boxes(self, filename):
        # load and parse the file
        tree = ElementTree.parse(filename)
        # get the root of the document
        root = tree.getroot()
        # extract each bounding box
        boxes = list()
        for box in root.findall('.//bndbox'):
            #xmin = int(box.find('xmin').text)
            #ymin = int(box.find('ymin').text)
            #xmax = int(box.find('xmax').text)
            #ymax = int(box.find('ymax').text)
            xmin = int(round(float(box.find('xmin').text)))
            ymin = int(round(float(box.find('ymin').text)))
            xmax = int(round(float(box.find('xmax').text)))
            ymax = int(round(float(box.find('ymax').text)))
            coords = [xmin, ymin, xmax, ymax]
            boxes.append(coords)
        # extract image dimensions
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        return boxes, width, height
 
    # load the masks for an image
    def load_mask(self, image_id):
        # get details of image
        info = self.image_info[image_id]
        # define box file location
        path = info['annotation']
        # load XML
        boxes, w, h = self.extract_boxes(path)
        # create one array for all masks, each on a different channel
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        # create masks
        class_ids = list()
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('cell'))
        return masks, asarray(class_ids, dtype='int32')
 
    # load an image reference
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']
    
# define a configuration for the model
class CellConfig(Config):
    # define the name of the configuration
    NAME = "cell_cfg"
    # number of classes (background + cell)
    NUM_CLASSES = 1 + 1
    # number of training steps per epoch
    STEPS_PER_EPOCH = 80 
    # 0.002 is reasonable, 0.02 is not
    LEARNING_RATE = 0.002
    # Dimension specification allows faster training
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    # 2 images per GPU works fine
    #IMAGES_PER_GPU = 1
    # Validation steps match the number of testing images
    VALIDATION_STEPS = 16
    # May leave this config
    #TRAIN_ROIS_PER_IMAGE = 200

# %%
#Directory is in current directory
cellDir = './'
# prepare train set
train_set = CellDataset()
train_set.load_dataset(cellDir, is_train=True)
train_set.prepare()
print('Training images: %d' % len(train_set.image_ids))
# prepare test/val set
test_set = CellDataset()
test_set.load_dataset(cellDir, is_train=False)
test_set.prepare()
print('Test images: \t%d' % len(test_set.image_ids))
# prepare config
config = CellConfig()
config.display()
# Out:
# Training images: 80
# Test images: 16
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# ...

# %%
# define the model for training
model = MaskRCNN(mode='training', model_dir='./', config=config)
# load weights (mscoco) and exclude the output layers
model.load_weights('mask_rcnn_cell_cfg_0001.h5', by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])
#model.load_weights('mask_rcnn_coco.h5', by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])
# Out:
# WARNING:tensorflow:From c:\users\roarke\miniconda3\envs\maskrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\roarke\miniconda3\envs\maskrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\users\roarke\miniconda3\envs\maskrcnn\lib\site-packages\keras\backend\tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From c:\users\roarke\miniconda3\envs\maskrcnn\lib\site-packages\tensorflow_core\python\ops\array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# train weights (output layers or 'heads')
model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=10, layers='heads')
# Out:
# Starting at epoch 0. LR=0.002
#
# Checkpoint Path: ./cell_cfg20191013T1437\mask_rcnn_cell_cfg_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# ...

# %%
from numpy import mean
from numpy import expand_dims

from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.utils import Dataset
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image

from matplotlib import pyplot
from matplotlib.patches import Rectangle

# %%
# calculate the mAP for a model on a given dataset
def evaluate_model(dataset, model, cfg):
    APs = list()
    for image_id in dataset.image_ids:
        # load image, bounding boxes and masks for the image id
        image, image_meta, gt_class_id, gt_bbox, gt_mask = load_image_gt(dataset, cfg, image_id, use_mini_mask=False)
        # convert pixel values (e.g. center)
        scaled_image = mold_image(image, cfg)
        # convert image into one sample
        sample = expand_dims(scaled_image, 0)
        # make prediction
        yhat = model.detect(sample, verbose=0)
        # extract results for first sample
        r = yhat[0]
        # calculate statistics, including AP
        AP, _, _, _ = compute_ap(gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r['masks'])
        # append APs
        APs.append(AP)
    # calculate the mean AP across all images
    mAP = mean(APs)
    return mAP

# %%
# plot a number of photos with ground truth and predictions (5 images)
def plot_actual_vs_predicted(dataset, model, cfg, n_images=5):
    # load image and mask
    for i in range(n_images):
        # load the image and mask
        image = dataset.load_image(i)
        mask, _ = dataset.load_mask(i)
        # convert pixel values (e.g. center)
        scaled_image = mold_image(image, cfg)
        # convert image into one sample
        sample = expand_dims(scaled_image, 0)
        # make prediction
        yhat = model.detect(sample, verbose=0)[0]
        # define subplot
        pyplot.subplot(n_images, 2, i*2+1)
        # plot raw pixel data
        pyplot.imshow(image)
        pyplot.title('Actual')
        # plot masks using alpha values
        for j in range(mask.shape[2]):
            pyplot.imshow(mask[:, :, j], cmap='gray', alpha=0.3)
        # get the context for drawing boxes
        pyplot.subplot(n_images, 2, i*2+2)
        # plot raw pixel data
        pyplot.imshow(image)
        pyplot.title('Predicted')
        ax = pyplot.gca()
        # plot each box
        for box in yhat['rois']:
            # get coordinates
            y1, x1, y2, x2 = box
            # calculate width and height of the box
            width, height = x2 - x1, y2 - y1
            # create the shape
            rect = Rectangle((x1, y1), width, height, fill=False, color='red')
            # draw the box
            ax.add_patch(rect)
    # show the figure
    pyplot.show()

# %%
# define the prediction configuration for small images (original image split into 16 images)
class SmallPredictionConfig(Config):
    # define the name of the configuration
    NAME = "cell_cfg"
    # number of classes (background + cell)
    NUM_CLASSES = 1 + 1
    # simplify GPU config
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    # specifying dimensions allow small image predictions
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256

# %%
# define the prediction configuration for large image detection
class PredictionConfig(Config):
    # define the name of the configuration
    NAME = "cell_cfg"
    # number of classes (background + cell)
    NUM_CLASSES = 1 + 1
    # simplify GPU config
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

# %%
# create config for predicting small images
cfg = SmallPredictionConfig()
# define the model for predictions
model = MaskRCNN(mode='inference', model_dir='./', config=cfg)
# load model weights
model_path = 'mask_rcnn_cell_cfg_0009.h5'
model.load_weights(model_path, by_name=True)

# %%
# classes to be predicted
class_names = ['None','Cell']
# dataset used for predictions
dataset = train_set
# iterate over 5 images to show resultss
for i in range (5):
    image = dataset.load_image(i)
    results = model.detect([image], verbose=0)
    # Visualize results
    r = results[0]
    visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names , r['scores'])

# %%
# evaluate model on training dataset
train_mAP = evaluate_model(train_set, model, cfg)
print("Train mAP: %.3f" % train_mAP)
# evaluate model on test dataset
test_mAP = evaluate_model(test_set, model, cfg)
print("Test mAP: %.3f" % test_mAP)
# plot predictions for train dataset
fig = plot_actual_vs_predicted(train_set, model, cfg)
# plot predictions for test dataset
fig2 = plot_actual_vs_predicted(test_set, model, cfg)
# Out:
# Train mAP: 0.932
# Test mAP: 0.740

# %%
# create config for detecting on larger images
cfg = PredictionConfig()
# define the model
model = MaskRCNN(mode='inference', model_dir='./', config=cfg)
# load model weights
model_path = 'mask_rcnn_cell_cfg_0009.h5'
model.load_weights(model_path, by_name=True)

# %%
# Final predictions visualized
testImage = CellDataset()
# path of images
imagePath = cellDir + 'YuliyaData'
testImage.load_final(imagePath)
testImage.prepare()
# choose single image to predict for
image = testImage.load_image(5)
results = model.detect([image], verbose=1)
# Visualize results
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])
# Out:
# Processing 1 images
# image                    shape: (224, 224, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
# imports for image manipulation
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from keras.preprocessing.image import load_img
import numpy as np

# %%
# returns the predicted data from an input image
def gatherData(dataset, model, cfg, imageNum):
    # load the image and mask
    image = dataset.load_image(imageNum)
    mask, _ = dataset.load_mask(imageNum)
    # convert pixel values (e.g. center)
    scaled_image = mold_image(image, cfg)
    # convert image into one sample
    sample = expand_dims(scaled_image, 0)
    # make prediction
    yhat = model.detect(sample, verbose=0)[0]
    return yhat

# %%
# Plots boxes 
def plotBoxes(yhat):
    # counts the amount of boxes as it progresses
    boxCount = 0
    pyplot.title('Prediction')
    pyplot.imshow(image)
    ax = pyplot.gca()
    # loop through rois in model detection
    for box in yhat['rois']:
        # get coordinates
        y1, x1, y2, x2 = box
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        # removes random bad guesses
        if ((width < 75) and (height < 75)):
            # create the shape
            rect = Rectangle((x1, y1), width, height, fill=False, color='red')
            # draw the box
            ax.add_patch(rect)   
            # count number of detections
            boxCount += 1
    # show the figure
    pyplot.show()
    # display total detections
    print("Number of cells detected: " + str(boxCount))

# %%
# Final predictions visualized
testImages = CellDataset()
# path of images
imagesPath = cellDir + 'YuliyaData'
testImages.load_final(imagesPath)
testImages.prepare()
# choose single image to predict for
imageNum = 0
# config needs to be for full size images
yhat = gatherData(testImages,model,cfg,imageNum)
plotBoxes(yhat)

# %%
# Plots boxes - iterates over the broken down image (into 16 images)
def plotBoxesOLD(yhats):
    boxCount = 0
    counter = 0
    image = stitchUp(images)
    pyplot.title('Stitched Image')
    pyplot.imshow(image)
    ax = pyplot.gca()
    for jj in range(4):
        for ii in range(4):
            # loop throguh rois in model detection
            for box in yhats[counter]['rois']:
                # get coordinates
                y1, x1, y2, x2 = box
                # calculate width and height of the box
                width, height = x2 - x1, y2 - y1
                # create the shape
                rect = Rectangle((x1+(56*ii), y1+(56*jj)), width, height, fill=False, color='red')
                # draw the box
                ax.add_patch(rect)   
                # count number of detections
                boxCount += 1
            counter += 1
    # show the figure
    pyplot.show()
    # display total detections
    print("Number of cells detected: " + str(boxCount))

# %%
# returns the predicted data from input images
def gatherDATA(dataset, model, cfg, n_images=16):
    # same as other gatherData function but works with small images 
    yhats = list()
    images = list()
    for i in range(n_images):
        # load the image and mask
        image = dataset.load_image(i)
        mask, _ = dataset.load_mask(i)
        # convert pixel values (e.g. center)
        scaled_image = mold_image(image, cfg)
        # convert image into one sample
        sample = expand_dims(scaled_image, 0)
        # make prediction
        yhat = model.detect(sample, verbose=0)[0]
        yhats.append(yhat)
        images.append(image)
    return yhats,images

# %%
# this function takes the broken down images and puts them back together as one
def stitchUp(images):
    # works through blocks of 4 on the x axis
    imgArray = np.append(images[0],images[1],axis=1)
    for ii in range(1,3):
        imgArray = np.append(imgArray,images[ii+1],axis=1)

    imgArray2 = np.append(images[4],images[5],axis=1)
    for ii in range(5,7):
        imgArray2 = np.append(imgArray2,images[ii+1],axis=1)
    imgArrayAPP = np.append(imgArray,imgArray2,axis=0)

    imgArray3 = np.append(images[8],images[9],axis=1)
    for ii in range(9,11):
        imgArray3 = np.append(imgArray3,images[ii+1],axis=1)
    imgArrayAPP = np.append(imgArrayAPP,imgArray3,axis=0)

    imgArray4 = np.append(images[12],images[13],axis=1)
    for ii in range(13,15):
        imgArray4 = np.append(imgArray4,images[ii+1],axis=1)
    imgArrayAPP = np.append(imgArrayAPP,imgArray4,axis=0)    
    imgTest = array_to_img(imgArrayAPP)
    # returns full size image
    return imgTest

# %%
# gather the data from the given set - config needs to be for small predictions
yhats,images = gatherDATA(test_set, model, cfg)
# display the bounding boxes on the image
plotBoxesOLD(yhats)
# strangely this works more effectively than full size
# Out:
# Number of cells detected: 152
